# %% [markdown]
# <a href="https://colab.research.google.com/github/psahu1110/Assignemt-4/blob/main/Assignment_14_(Q2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # predicting turbine energy yield (TEY) using ambient variables as features.

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %% [markdown]
# READING THE DATASET

# %%
df = pd.read_csv(r"C:\Users\Sujal Sahu\Downloads\gas_turbines.csv")

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df.tail()
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498

# %%
df.shape
# Out:
# (15039, 11)

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# ...

# %%
data=pd.DataFrame(df)
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
bins=[1,10,20]

# %%
groups=["low","high"]

# %%
data1["sales"]=pd.cut(data1.Sales,bins,labels=groups)
data1

# %%
df['TEY'].value_counts()
# Out:
# 133.74    150
# 133.78    148
# 133.67    143
# 133.76    142
# 133.79    127
#          ...
# 144.49      1
# 122.83      1
# 146.05      1
# 113.91      1
# 130.43      1
# Name: TEY, Length: 4207, dtype: int64

# %%
df.info()

# %% [markdown]
# PREPROCESSING THE DATA

# %%
X = df.drop(columns=['TEY'])
Y = df['TEY']

# %%
X

# %%
Y

# %% [markdown]
# SPLITTING THE DATASET INTO TRAIN AND TEST SETS

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# BUILDING THE MODEL

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# COMPILING THE MODEL

# %%
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %% [markdown]
# TRAINING THE MODEL

# %%
model.fit(X_train, Y_train, epochs=150, batch_size=9)
# Out:
# Epoch 1/150
# 1337/1337 [==============================] - 5s 3ms/step - loss: 133.2470 - mean_absolute_error: 133.2470
# Epoch 2/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2471 - mean_absolute_error: 133.2471
# Epoch 3/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2471 - mean_absolute_error: 133.2471
# Epoch 4/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2471 - mean_absolute_error: 133.2471
# Epoch 5/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2473 - mean_absolute_error: 133.2473
# Epoch 6/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2472 - mean_absolute_error: 133.2472
# Epoch 7/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2472 - mean_absolute_error: 133.2472
# Epoch 8/150
# 1337/1337 [==============================] - 4s 3ms/step - loss: 133.2471 - mean_absolute_error: 133.2471
# Epoch 9/150
# ...

# %% [markdown]
# EVALUATING THE MODEL

# %%
score = model.evaluate(X_test, Y_test, batch_size=9)
# Out:
# 335/335 [==============================] - 1s 2ms/step - loss: 132.9540 - mean_absolute_error: 132.9540
